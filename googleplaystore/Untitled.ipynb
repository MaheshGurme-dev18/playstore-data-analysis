# %%
import pandas as pd

# %%
df=pd.read_csv("googleplaystore (1).csv")

# %%
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
df.isna().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
df.isna().sum().sort_values(ascending=False)
# Out:
# Rating            1474
# Current Ver          8
# Android Ver          3
# Content Rating       1
# Type                 1
# Size                 0
# Reviews              0
# Category             0
# App                  0
# Price                0
# Installs             0
# Last Updated         0
# Genres               0
# dtype: int64

# %%
  df.dropna(inplace=True)

# %%
df.isna().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       0
# Android Ver       0
# dtype: int64

# %%
df["Reviews"].astype(float)
# Out:
# 0           159.0
# 1           967.0
# 2         87510.0
# 3        215644.0
# 4           967.0
#            ...
# 10834         7.0
# 10836        38.0
# 10837         4.0
# 10839       114.0
# 10840    398307.0
# Name: Reviews, Length: 9360, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9360 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             9360 non-null   object
#  1   Category        9360 non-null   object
#  2   Rating          9360 non-null   float64
#  3   Reviews         9360 non-null   object
#  4   Size            9360 non-null   object
#  5   Installs        9360 non-null   object
#  6   Type            9360 non-null   object
#  7   Price           9360 non-null   object
#  8   Content Rating  9360 non-null   object
#  9   Genres          9360 non-null   object
#  10  Last Updated    9360 non-null   object
#  11  Current Ver     9360 non-null   object
#  12  Android Ver     9360 non-null   object
# dtypes: float64(1), object(12)
# memory usage: 1023.8+ KB

# %%
df.loc[df.duplicated(subset=["App"], keep=False) & ~df.duplicated(keep=False)].sort_values(by="App").head(10)
# Out:
#                                   App Category  Rating   Reviews Size  \
# 5415          365Scores - Live Scores   SPORTS     4.6    666246  25M
# 3083          365Scores - Live Scores   SPORTS     4.6    666521  25M
# 1844                      8 Ball Pool     GAME     4.5  14200550  52M
# 1703                      8 Ball Pool     GAME     4.5  14198602  52M
# 1871                      8 Ball Pool     GAME     4.5  14201891  52M
# 1675                      8 Ball Pool     GAME     4.5  14198297  52M
# 3953                      8 Ball Pool   SPORTS     4.5  14184910  52M
# 1755                      8 Ball Pool     GAME     4.5  14200344  52M
# 1970                      8 Ball Pool     GAME     4.5  14201604  52M
# 559   95Live -SG#1 Live Streaming App   DATING     4.1      4953  15M
#
#           Installs  Type Price Content Rating  Genres    Last Updated  \
# 5415   10,000,000+  Free     0       Everyone  Sports   July 29, 2018
# ...

# %%
 df.duplicated(keep=False).sum()
# Out:
# np.int64(876)

# %%
df.loc[df.duplicated(subset=["App"], keep=False) & ~df.duplicated(keep=False)].sort_values(by=["App","Reviews"]).head(10)
# Out:
#                                   App Category  Rating   Reviews Size  \
# 5415          365Scores - Live Scores   SPORTS     4.6    666246  25M
# 3083          365Scores - Live Scores   SPORTS     4.6    666521  25M
# 3953                      8 Ball Pool   SPORTS     4.5  14184910  52M
# 1675                      8 Ball Pool     GAME     4.5  14198297  52M
# 1703                      8 Ball Pool     GAME     4.5  14198602  52M
# 1755                      8 Ball Pool     GAME     4.5  14200344  52M
# 1844                      8 Ball Pool     GAME     4.5  14200550  52M
# 1970                      8 Ball Pool     GAME     4.5  14201604  52M
# 1871                      8 Ball Pool     GAME     4.5  14201891  52M
# 559   95Live -SG#1 Live Streaming App   DATING     4.1      4953  15M
#
#           Installs  Type Price Content Rating  Genres    Last Updated  \
# 5415   10,000,000+  Free     0       Everyone  Sports   July 29, 2018
# ...

# %%
df.sort_values(by=["App","Reviews"],inplace=True)

# %%
df.drop_duplicates(subset=["App"],keep="last",inplace=True)

# %%
df["Category"].value_counts()
# Out:
# Category
# FAMILY                 1654
# GAME                    895
# TOOLS                   718
# FINANCE                 302
# PRODUCTIVITY            301
# LIFESTYLE               301
# PERSONALIZATION         296
# MEDICAL                 290
# BUSINESS                263
# PHOTOGRAPHY             263
# SPORTS                  260
# COMMUNICATION           256
# HEALTH_AND_FITNESS      244
# NEWS_AND_MAGAZINES      204
# SOCIAL                  203
# TRAVEL_AND_LOCAL        187
# SHOPPING                180
# BOOKS_AND_REFERENCE     169
# VIDEO_PLAYERS           149
# DATING                  134
# MAPS_AND_NAVIGATION     118
# EDUCATION               105
# FOOD_AND_DRINK           94
# ENTERTAINMENT            86
# AUTO_AND_VEHICLES        73
# WEATHER                  72
# LIBRARIES_AND_DEMO       63
# HOUSE_AND_HOME           61
# ART_AND_DESIGN           58
# COMICS                   54
# PARENTING                50
# EVENTS                   45
# ...

# %%
df["Category"]=df["Category"].str.replace('_',' ')

# %%
df["Category"]=df["Category"].str.capitalize()

# %%
df.head()
# Out:
#                                 App            Category  Rating Reviews  Size  \
# 8532  +Download 4 Instagram Twitter              Social     4.5   40467   22M
# 324      - Free Comics - Comic Apps              Comics     3.5     115  9.1M
# 4541                             .R               Tools     4.5     259  203k
# 4636                         /u/app       Communication     4.7     573   53M
# 5940                         058.ba  News and magazines     4.4      27   14M
#
#         Installs  Type Price Content Rating            Genres  \
# 8532  1,000,000+  Free     0       Everyone            Social
# 324      10,000+  Free     0     Mature 17+            Comics
# 4541     10,000+  Free     0       Everyone             Tools
# 4636     10,000+  Free     0     Mature 17+     Communication
# 5940        100+  Free     0       Everyone  News & Magazines
#
#             Last Updated Current Ver Android Ver
# 8532      August 2, 2018        5.03  4.1 and up
# ...

# %%
df.loc[df["Size"].str.contains(',')]
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []

# %%
df.loc[df["Price"] == "0"]
# Out:
#                                                    App            Category  \
# 8532                     +Download 4 Instagram Twitter              Social
# 324                         - Free Comics - Comic Apps              Comics
# 4541                                                .R               Tools
# 4636                                            /u/app       Communication
# 5940                                            058.ba  News and magazines
# ...                                                ...                 ...
# 9222                                英漢字典 EC Dictionary              Family
# 6420                                       감성학원 BL 첫사랑              Comics
# 2575     💘 WhatsLov: Smileys of love, stickers and GIF              Social
# 7559  📏 Smart Ruler ↔️ cm/inch measuring for homework!               Tools
# 882   🔥 Football Wallpapers 4K | Full HD Backgrounds 😍       Entertainment
#
#       Rating Reviews                Size    Installs  Type Price  \
# ...

# %% [markdown]
# what company have most review

# %%
df.sort_values(by="Reviews", ascending=False).head()
# Out:
#                                     App          Category  Rating Reviews  \
# 2989             GollerCepte Live Score            Sports     4.2    9992
# 4970       Ad Block REMOVER - NEED ROOT             Tools     3.3     999
# 2723                SnipSnap Coupon App          Shopping     4.2    9975
# 3229                         DreamTrips  Travel and local     4.7    9971
# 3079  US Open Tennis Championships 2018            Sports     4.0    9971
#
#      Size    Installs  Type Price Content Rating          Genres  \
# 2989  31M  1,000,000+  Free     0       Everyone          Sports
# 4970  91k    100,000+  Free     0       Everyone           Tools
# 2723  18M  1,000,000+  Free     0       Everyone        Shopping
# 3229  22M    500,000+  Free     0           Teen  Travel & Local
# 3079  33M  1,000,000+  Free     0       Everyone          Sports
#
#            Last Updated Current Ver Android Ver
# 2989       May 23, 2018         6.5  4.1 and up
# ...

# %%
df.loc[df["Reviews"]==df["Reviews"].max()]
# Out:
#                          App Category  Rating Reviews Size    Installs  Type  \
# 2989  GollerCepte Live Score   Sports     4.2    9992  31M  1,000,000+  Free
#
#      Price Content Rating  Genres  Last Updated Current Ver Android Ver
# 2989     0       Everyone  Sports  May 23, 2018         6.5  4.1 and up

# %%
df["Category"].value_counts()
# Out:
# Category
# Family                 1654
# Game                    895
# Tools                   718
# Finance                 302
# Productivity            301
# Lifestyle               301
# Personalization         296
# Medical                 290
# Business                263
# Photography             263
# Sports                  260
# Communication           256
# Health and fitness      244
# News and magazines      204
# Social                  203
# Travel and local        187
# Shopping                180
# Books and reference     169
# Video players           149
# Dating                  134
# Maps and navigation     118
# Education               105
# Food and drink           94
# Entertainment            86
# Auto and vehicles        73
# Weather                  72
# Libraries and demo       63
# House and home           61
# Art and design           58
# Comics                   54
# Parenting                50
# Events                   45
# ...

# %% [markdown]
# the which category belondgs the most expensive app

# %%
df.sort_values(by="Price" , ascending=False).head()
# Out:
#                                 App       Category  Rating Reviews  \
# 8532  +Download 4 Instagram Twitter         Social     4.5   40467
# 368                      My magenta  Communication     3.9   42370
# 3588               My baby firework      Parenting     3.7    4976
# 3576                  My baby Piano      Parenting     3.9   17941
# 3591                  My baby Phone      Parenting     3.7    9293
#
#                     Size    Installs  Type Price Content Rating  \
# 8532                 22M  1,000,000+  Free     0       Everyone
# 368                  37M  1,000,000+  Free     0       Everyone
# 3588                2.8M  1,000,000+  Free     0       Everyone
# 3576  Varies with device  5,000,000+  Free     0       Everyone
# 3591                2.4M  1,000,000+  Free     0       Everyone
#
#                        Genres    Last Updated         Current Ver  \
# 8532                   Social  August 2, 2018                5.03
# ...

# %%
df.loc[df["Category"]=="Game"].sort_values(by="Price",ascending=False)
# Out:
#                                                      App Category  Rating  \
# 1997                     1LINE – One Line with One Touch     Game     4.6
# 1809                 New YAHTZEE® With Buddies Dice Game     Game     4.1
# 5638                      Nights at Cube Pizzeria 3D – 4     Game     4.1
# 5634                       Nights at Slender Pizzeria 3D     Game     4.1
# 4243                                             NinJump     Game     4.3
# ...                                                  ...      ...     ...
# 6088                      Wolf of the BF:Commando MOBILE     Game     3.4
# 7665     Chinese Chess 3D Online (Xiangqi, 象棋, co tuong)     Game     3.5
# 10060                                An Elite Warrior Ex     Game     4.7
# 9592    Poker Equity Calculator Pro for No Limit Hold'em     Game     4.0
# 9165   League of Stickman 2018- Ninja Arena PVP(Dream...     Game     4.4
#
#       Reviews Size     Installs  Type  Price Content Rating     Genres  \
# ...

# %%
df.query("Category == 'Game'").sort_values(by="Price",ascending=False)
# Out:
#                                                      App Category  Rating  \
# 1997                     1LINE – One Line with One Touch     Game     4.6
# 1809                 New YAHTZEE® With Buddies Dice Game     Game     4.1
# 5638                      Nights at Cube Pizzeria 3D – 4     Game     4.1
# 5634                       Nights at Slender Pizzeria 3D     Game     4.1
# 4243                                             NinJump     Game     4.3
# ...                                                  ...      ...     ...
# 6088                      Wolf of the BF:Commando MOBILE     Game     3.4
# 7665     Chinese Chess 3D Online (Xiangqi, 象棋, co tuong)     Game     3.5
# 10060                                An Elite Warrior Ex     Game     4.7
# 9592    Poker Equity Calculator Pro for No Limit Hold'em     Game     4.0
# 9165   League of Stickman 2018- Ninja Arena PVP(Dream...     Game     4.4
#
#       Reviews Size     Installs  Type  Price Content Rating     Genres  \
# ...

# %% [markdown]
# which is the most popular apps by finance

# %%
df.query("Category == 'Finance'").sort_values(by="Installs",ascending=False)
# Out:
#                                                   App Category  Rating  \
# 6874                                    Meu Cartão BV  Finance     4.1
# 9023                                  Direct Express®  Finance     4.5
# 6987                            Bitcoin Ticker Widget  Finance     4.6
# 1134                           Bloomberg Professional  Finance     4.1
# 1101   Prism Pay Bills, Track Money, Personal Finance  Finance     4.6
# ...                                               ...      ...     ...
# 10160                         EZ Financial Calculator  Finance     4.4
# 5358                                       I am Rich!  Finance     3.8
# 10288                         FD Community FCU Mobile  Finance     4.7
# 5911                     Ba Financial Calculator plus  Finance     4.4
# 10298    FD Calculator | Term Deposit | Fixed Deposit  Finance     4.8
#
#       Reviews                Size  Installs  Type    Price Content Rating  \
# ...

# %%
df.loc[df["price
